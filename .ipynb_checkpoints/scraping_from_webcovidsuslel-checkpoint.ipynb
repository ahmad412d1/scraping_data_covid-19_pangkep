# %% [markdown]
# <h1>Web Scraping From website Covid Sul-Sel</h1>
# sumber : <a href="https://towardsdatascience.com/web-scraping-html-tables-with-python-c9baba21059">Web Scraping HTML Tables with Python</a>

# %%
#load library
import numpy as np
import pandas as pd
import lxml.html as lh
from bs4 import BeautifulSoup
import requests

# %%
#request url target
URL = 'https://covid19.sulselprov.go.id/data'
#if not succes (200) do this
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36 Edg/89.0.774.50"}
page = requests.get(URL, headers=headers)
print(page)
# Out:
# <Response [200]>

# %%
if page.status_code == 200:
    print('Success!')
elif page.status_code == 404:
    print('Not Found.')
# Out:
# Success!

# %%
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#tr_elements #see through inspect element in the website

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [6, 11, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[2]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"1"
# 2:"Kota Makassar"
# 3:"672"
# 4:"3728"
# 5:"4400"
# 6:"0"
# 7:"12"
# 8:"147"
# 9:"159"
# 10:"157"
# 11:"29641"
# 12:"539"
# 13:"30337"
# 14:"34880"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(2,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 14, the //tr data is not from our table 
    if len(T)!=14:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54]

# %%
Dict={title:column for (title,column) in col}
data_covid_sulsel=pd.DataFrame(Dict)

# %%
data_covid_sulsel.head()
# Out:
#    1         Kota Makassar  672  3728  4400  0  12  147  159  157  29641  539  \
# 0  1         Kota Makassar  672  3728  4400  0  12  147  159  157  29641  539
# 1  2        Kabupaten Gowa   46   823   869  0   1   20   21   38   5324   64
# 2  3  Kabupaten Luwu Timur    2   525   527  0   0    6    6    5   2710    9
# 3  4      Kabupaten Sinjai   11   289   300  0   0    1    1    6   2669   14
# 4  5       Kabupaten Maros   15   334   349  0   0    8    8    5   2217   25
#
#    30337  34880
# 0  30337  34880
# 1   5426   6315
# 2   2724   3257
# 3   2689   2990
# 4   2247   2603

# %%
colnames = ["No", 'Kabupaten/Kota', "suspek follow up", "suspek discarded", "suspek total", 'probable follow up', "probable sembuh", 'probable meninggal',
            'probable total', 'konfirmasi dirawat', 'konfirmasi sembuh', 'konfirmasi meninggal', 'konfirmasi total', 'akumulasi']

# %% [markdown]
# mengganti nama-nama column https://stackoverflow.com/questions/38101009/changing-multiple-column-names-but-not-all-of-them-pandas-python

# %%
#giving new names to the columns
column_indices = [np.arange(0,14)]
new_names = ["No", 'Kabupaten/Kota', "suspek follow up", "suspek discarded", "suspek total", 'probable follow up', "probable sembuh", 'probable meninggal',
            'probable total', 'konfirmasi dirawat', 'konfirmasi sembuh', 'konfirmasi meninggal', 'konfirmasi total', 'akumulasi']
old_names = data_covid_sulsel.columns[column_indices]
data_covid_sulsel.rename(columns=dict(zip(old_names, new_names)), inplace=True)
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:4307: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)

# %%
data_covid_sulsel
# Out:
#     No                      Kabupaten/Kota  suspek follow up  \
# 0    1                       Kota Makassar               672
# 1    2                      Kabupaten Gowa                46
# 2    3                Kabupaten Luwu Timur                 2
# 3    4                    Kabupaten Sinjai                11
# 4    5                     Kabupaten Maros                15
# 5    6                 Kabupaten Jeneponto                 5
# 6    7                         Kota Palopo                 9
# 7    8                      Kabupaten Bone                 0
# 8    9                Kabupaten Luwu Utara                 0
# 9   10                   Kabupaten Pinrang                10
# 10  11                       Kota Parepare                27
# 11  12  Kabupaten Pangkajene Dan Kepulauan                55
# 12  13                 Kabupaten Bulukumba                34
# 13  14                   Kabupaten Takalar                50
# 14  15                   Kabupaten Soppeng                 3
# 15  16         Kabupaten Sidenreng Rappang                34
# 16  17                  Kabupaten Bantaeng                 2
# 17  18               Kabupaten Tana Toraja                 4
# 18  19                     Kabupaten Barru                 0
# 19  20                      Kabupaten Wajo                 4
# 20  21                      Kabupaten Luwu                 0
# 21  22                  Kabupaten Enrekang                34
# 22  23         Kabupaten Kepulauan Selayar                 2
# 23  24              Kabupaten Toraja Utara                 1
# 24  25        Rekreasi Duta Covid19 SulSel                 1
# 25  26                 Kabupaten/Kota lain                 0
# 26  27                        RS Lain-lain                 0
# 27   1                       Kota Makassar               672
# 28   2                      Kabupaten Gowa                46
# 29   3                Kabupaten Luwu Timur                 2
# 30   4                    Kabupaten Sinjai                11
# 31   5                     Kabupaten Maros                15
# 32   6                 Kabupaten Jeneponto                 5
# 33   7                         Kota Palopo                 9
# 34   8                      Kabupaten Bone                 0
# 35   9                Kabupaten Luwu Utara                 0
# 36  10                   Kabupaten Pinrang                10
# 37  11                       Kota Parepare                27
# 38  12  Kabupaten Pangkajene Dan Kepulauan                55
# 39  13                 Kabupaten Bulukumba                34
# 40  14                   Kabupaten Takalar                50
# 41  15                   Kabupaten Soppeng                 3
# 42  16         Kabupaten Sidenreng Rappang                34
# 43  17                  Kabupaten Bantaeng                 2
# 44  18               Kabupaten Tana Toraja                 4
# 45  19                     Kabupaten Barru                 0
# 31                   8               8                   5               2217
# 32                   2               2                   2               1408
# 33                   1               1                   7               1445
# 34                   4               4                   5               1296
# 35                   0               0                   1               1300
# 36                   5               5                   4                928
# 37                   0               0                   1               1211
# 38                   2               2                   1               1235
# 39                   6               8                   1               1002
# 40                   2               2                   6               1227
# 41                   1               1                   5               1058
# 42                   4               4                   1                942
# 43                   0               0                   1                879
# 44                   2               2                  15                676
# 45                   1               1                   0                859
# 46                   3               3                   0                798
# 47                   0               0                   1                610
# 48                   3               3                   2                296
# 49                   3               3                   2                453
# 50                   1               1                   4                219
# 51                   0               0                   0                  0
# 52                   0               0                   0                  0
# 53                   0               0                   0                  0
#
#     konfirmasi meninggal  konfirmasi total  akumulasi
# 0                    539             30337      34880
# 1                     64              5426       6315
# 2                      9              2724       3257
# 3                     14              2689       2990
# 4                     25              2247       2603
# 5                     11              1421       1989
# 6                     21              1473       1666
# 7                     11              1312       1656
# 8                     22              1323       1641
# 9                     44               976       1578
# 10                    24              1236       1513
# 11                    30              1266       1507
# 12                    12              1015       1458
# 13                    16              1249       1408
# 14                    17              1080       1202
# 15                     9               952       1125
# 16                     7               887       1061
# 17                     2               693        955
# 18                     5               864        946
# 19                    19               817        916
# 20                     8               619        861
# 21                    12               310        654
# 22                     9               464        555
# 23                     5               228        412
# 24                     0                 0          8
# 25                     0                 0          0
# 26                     0                 0          0
# 27                   539             30337      34880
# 28                    64              5426       6315
# 29                     9              2724       3257
# 30                    14              2689       2990
# 31                    25              2247       2603
# 32                    11              1421       1989
# 33                    21              1473       1666
# 34                    11              1312       1656
# 35                    22              1323       1641
# 36                    44               976       1578
# 37                    24              1236       1513
# 38                    30              1266       1507
# 39                    12              1015       1458
# 40                    16              1249       1408
# 41                    17              1080       1202
# 42                     9               952       1125
# 43                     7               887       1061
# 44                     2               693        955
# 45                     5               864        946
# 46                    19               817        916
# 47                     8               619        861
# 48                    12               310        654
# 49                     9               464        555
# 50                     5               228        412
# 51                     0                 0          8
# 52                     0                 0          0
# 53                     0                 0          0

# %%
#save file in csv format
data_covid_sulsel.to_csv('data/7 mei 2021.csv', index=False)

# %%
#get the information
data_covid_sulsel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   No                    27 non-null     object
#  1   Kabupaten/Kota        27 non-null     object
#  2   suspek follow up      27 non-null     int64
#  3   suspek discarded      27 non-null     int64
#  4   suspek total          27 non-null     int64
#  5   probable follow up    27 non-null     int64
#  6   probable sembuh       27 non-null     int64
#  7   probable meninggal    27 non-null     int64
#  8   probable total        27 non-null     int64
#  9   konfirmasi dirawat    27 non-null     int64
#  10  konfirmasi sembuh     27 non-null     int64
#  11  konfirmasi meninggal  27 non-null     int64
#  12  konfirmasi total      27 non-null     int64
#  13  akumulasi             27 non-null     int64
# dtypes: int64(12), object(2)
# memory usage: 3.1+ KB
